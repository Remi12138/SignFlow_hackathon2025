# %%
# %run app.py
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# Model loaded successfully!
#  * Serving Flask app 'app'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:8088
#  * Running on http://192.168.1.71:8088
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug:127.0.0.1 - - [22/Feb/2025 13:29:24] "GET / HTTP/1.1" 200 -
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# INFO:werkzeug:127.0.0.1 - - [22/Feb/2025 13:29:44] "POST /predict HTTP/1.1" 200 -
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# INFO:werkzeug:127.0.0.1 - - [22/Feb/2025 13:29:46] "POST /predict HTTP/1.1" 200 -
# ...
